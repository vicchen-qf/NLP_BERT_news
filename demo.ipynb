# %%
from classification_process import bert_classifier

# %%
data = bert_classifier('D:/desktop/NLP/demo/data/class/order_test.xlsx')
# Out:
# D:\anaconda_19\envs\PythonGPU\lib\site-packages\transformers\tokenization_utils_base.py:2149: FutureWarning: The `pad_to_max_length` argument is deprecated and will be removed in a future version, use `padding=True` or `padding='longest'` to pad to the longest sequence in the batch, or use `padding='max_length'` to pad to a max length. In this case, you can give a specific length with `max_length` (e.g. `max_length=45`) or leave max_length to None to pad to the maximal input size of the model (e.g. 512 for Bert).
#   warnings.warn(
# ...

# %%
data
# Out:
#                   times                               titles  label  \
# 0   2020-05-07 08:41:15           中國加快5G投資、需求衝！日本機器人訂單額6季來首增      2
# 1   2020-05-07 11:31:00  △個股：瑞穎(8083)在手訂單直達6月底，自動倉儲物流為今年成長動能      2
# 2   2020-05-07 13:48:04             永冠Q1每股虧損1.06元；在手訂單仍處歷史高位      1
# 3   2020-05-07 16:44:45               陸商務部：外貿企業仍面臨訂單取消或延期等困境      0
# 4   2020-05-07 18:45:03         〈神盾法說〉印度封城干擾+需求趨緩 5、6月訂單能見度低      0
# ..                  ...                                  ...    ...
# 250 2020-07-22 05:36:58              《大陸產業》美團看未來5年 外賣訂單增3~4倍      2
# 251 2020-07-22 10:13:47                       大田訂單增溫，7月營收拚新高      2
# 252 2020-07-23 02:51:07                         聯電大爆發 晶圓訂單滿手      2
# 253 2020-07-23 08:04:52               聯電大爆發 晶圓訂單滿手(經濟日報，無內文)      2
# 254 2020-07-23 10:27:00  緯創、和碩入股紅色供應鏈！聯手立訊搶iPhone訂單 抗衡鴻海龍頭地位      2
#
#                                               contents  groups  predict_label
# ...

# %%
from sentiment_process import sent_score
# Out:
# Some layers from the model checkpoint at bert-base-chinese were not used when initializing TFBertModel: ['nsp___cls', 'mlm___cls']
# - This IS expected if you are initializing TFBertModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing TFBertModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# All the layers of TFBertModel were initialized from the model checkpoint at bert-base-chinese.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use TFBertModel for predictions without further training.
# ...

# %%
# %%time
news = {'times': '2020-08-20 03:00:12',
  'titles': '《業績-電子零件》IA及遠距生活助攻 台達Q2毛利率、營業淨利創新高',
  'label': '2'}
news = sent_score(news)
print(news)
# Out:
# WARNING:tensorflow:The parameters `output_attentions`, `output_hidden_states` and `use_cache` cannot be updated when calling a model.They have to be set to True/False in the config object (i.e.: `config=XConfig.from_pretrained('name', output_attentions=True)`).
# WARNING:tensorflow:The parameter `return_dict` cannot be set in graph mode and will always be set to `True`.
# {'times': '2020-08-20 03:00:12', 'titles': '《業績-電子零件》IA及遠距生活助攻 台達Q2毛利率、營業淨利創新高', 'label': '2', 'QA_word': '創新高', 'score': 0.9651885786679695}
# Wall time: 3.23 s

# %%
from sentiment_process import update_score

# %%
data = update_score(data)
# Out:
# D:\anaconda_19\envs\PythonGPU\lib\site-packages\pandas\core\indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)

# %%
data
# Out:
#                   times                               titles  label  \
# 0   2020-05-07 08:41:15           中國加快5G投資、需求衝！日本機器人訂單額6季來首增      2
# 1   2020-05-07 11:31:00  △個股：瑞穎(8083)在手訂單直達6月底，自動倉儲物流為今年成長動能      2
# 2   2020-05-07 13:48:04             永冠Q1每股虧損1.06元；在手訂單仍處歷史高位      1
# 3   2020-05-07 16:44:45               陸商務部：外貿企業仍面臨訂單取消或延期等困境      0
# 4   2020-05-07 18:45:03         〈神盾法說〉印度封城干擾+需求趨緩 5、6月訂單能見度低      0
# ..                  ...                                  ...    ...
# 250 2020-07-22 05:36:58              《大陸產業》美團看未來5年 外賣訂單增3~4倍      2
# 251 2020-07-22 10:13:47                       大田訂單增溫，7月營收拚新高      2
# 252 2020-07-23 02:51:07                         聯電大爆發 晶圓訂單滿手      2
# 253 2020-07-23 08:04:52               聯電大爆發 晶圓訂單滿手(經濟日報，無內文)      2
# 254 2020-07-23 10:27:00  緯創、和碩入股紅色供應鏈！聯手立訊搶iPhone訂單 抗衡鴻海龍頭地位      2
#
#                                               contents  groups  predict_label  \
# ...
